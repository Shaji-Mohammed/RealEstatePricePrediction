# %%
# %pip install -r ../../requirements.txt

import pandas as pd
# Out:
# ...
#   Using cached scikit_learn-1.9.0-cp314-cp314-macosx_12_0_arm64.whl.metadata (11 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 19.1 MB/s  0:00:009.3 MB/s eta 0:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.4/20.4 MB 22.8 MB/s  0:00:003.4 MB/s eta 0:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [scikit-learn]0m 4/5 [scikit-learn]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
toronto_data = pd.read_csv('../data/toronto_real_estate_public_area.csv')

# %%
toronto_data.head()
# Out:
#    property_id period home_type_bucket  status   last_status home_type  \
# 0            1   sale            CONDO  ACTIVE  PRICE_CHANGE     CONDO
# 1            2   sale            CONDO  ACTIVE           NEW     CONDO
# 2            3   sale            CONDO  ACTIVE           NEW     CONDO
# 3            4   sale            CONDO  ACTIVE           NEW     CONDO
# 4            5   sale            CONDO  ACTIVE           NEW     CONDO
#
#       price  list_price  sold_price                 list_date  \
# 0  388000.0    388000.0         NaN  2026-04-12T13:29:08.000Z
# 1  385000.0    385000.0         NaN  2026-05-28T11:31:44.000Z
# 2  299000.0    299000.0         NaN  2026-06-09T10:35:34.000Z
# 3  399000.0    399000.0         NaN  2026-06-20T09:57:05.000Z
# 4  399999.0    399999.0         NaN  2026-06-03T21:38:51.000Z
#
#                        neighbourhood   latitude  longitude  bedrooms  \
# 0  Waterfront Communities The Island  43.648879 -79.388044       1.0
# ...
